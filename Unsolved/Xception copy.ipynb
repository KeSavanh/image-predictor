# %%
# Dependencies
import matplotlib.pyplot as plt
# %matplotlib inline

import os
import numpy as np
import tensorflow as tf

from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.xception import (
    Xception, preprocess_input, decode_predictions)

# %%
# Load the Xception model
# https://keras.io/api/applications/xception/
model = Xception(include_top=True, weights="imagenet")

# %%
# Default Image Size for Xception
image_size = (299, 299)

# %%
# Load the image and resize to the input dimensions that Xception
# was trained with


image_path = os.path.join("..", "Images", "pup.jpg")
img = image.load_img(image_path, target_size=image_size)
plt.imshow(img)

# %%
# Preprocess image for model prediction
# This step handles scaling and normalization for Xception
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
# Make predictions
predictions = model.predict(x)
print('Predicted:', decode_predictions(predictions, top=3))
plt.imshow(img)
# Out:
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/data/imagenet_class_index.json
# 40960/35363 [==================================] - 0s 1us/step
# Predicted: [[('n02111277', 'Newfoundland', 0.2543829), ('n02104365', 'schipperke', 0.09033302), ('n02108551', 'Tibetan_mastiff', 0.08263815)]]

# %%
# Refactor above steps into reusable function
def predict(image_path):
  img = image.load_img(image_path, target_size=image_size)
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis=0)
  x = preprocess_input(x)
  predictions = model.predict(x)
  plt.imshow(img)
  print('Predicted:', decode_predictions(predictions, top=3))

# %%
# Predict labels for new image
image_path = os.path.join("..", "Images", "kitten.jpg")
predict(image_path)
# Out:
# Predicted: [[('n02123394', 'Persian_cat', 0.18114997), ('n02123045', 'tabby', 0.13359602), ('n02123159', 'tiger_cat', 0.08032113)]]

# %%
# Predict labels for new image
image_path = os.path.join("..", "Images", "kitten1.png")
predict(image_path)
# Out:
# Predicted: [[('n02085620', 'Chihuahua', 0.43606004), ('n02123597', 'Siamese_cat', 0.042702574), ('n02124075', 'Egyptian_cat', 0.0358381)]]

# %%
# Predict labels for new image
image_path = os.path.join("..", "Images", "kitten2.jpeg")
predict(image_path)
# Out:
# Predicted: [[('n02328150', 'Angora', 0.3786217), ('n02325366', 'wood_rabbit', 0.045007717), ('n04033995', 'quilt', 0.03332045)]]

# %%
# Predict labels for new image
image_path = os.path.join("..", "Images", "animal.jpeg")
predict(image_path)
# Out:
# Predicted: [[('n02342885', 'hamster', 0.2623516), ('n02346627', 'porcupine', 0.10849682), ('n02441942', 'weasel', 0.05643541)]]

# %%
# Predict labels for new image
image_path = os.path.join("..", "Images", "dog.jpeg")
predict(image_path)
# Out:
# Predicted: [[('n02110958', 'pug', 0.85961294), ('n02108915', 'French_bulldog', 0.009640378), ('n02112706', 'Brabancon_griffon', 0.007377322)]]

# %%
# Predict labels for new image
image_path = os.path.join("..", "Images", "x-ray-COVID-19.jpeg")
predict(image_path)
# Out:
# Predicted: [[('n03388043', 'fountain', 0.81734896), ('n03729826', 'matchstick', 0.027957276), ('n01910747', 'jellyfish', 0.014028952)]]

# %%
# Predict labels for new image
image_path = os.path.join("..", "Images", "cat.jpeg")
predict(image_path)
# Out:
# Predicted: [[('n02123045', 'tabby', 0.07807934), ('n02124075', 'Egyptian_cat', 0.076741934), ('n02123159', 'tiger_cat', 0.043796822)]]

# %%
# Predict labels for new image
image_path = os.path.join("..", "Images", "dorphin.jpeg")
predict(image_path)
# Out:
# Predicted: [[('n03724870', 'mask', 0.46036085), ('n03763968', 'military_uniform', 0.027280485), ('n04229816', 'ski_mask', 0.023932692)]]

# %%
# Predict labels for new image
image_path = os.path.join("..", "Images", "images.jpeg")
predict(image_path)
# Out:
# Predicted: [[('n02066245', 'grey_whale', 0.43106243), ('n02641379', 'gar', 0.18984541), ('n01484850', 'great_white_shark', 0.057093203)]]

# %%
# Predict labels for new image
image_path = os.path.join("..", "Images", "images2.jpeg")
predict(image_path)
# Out:
# Predicted: [[('n02071294', 'killer_whale', 0.6963365), ('n02066245', 'grey_whale', 0.12882663), ('n01484850', 'great_white_shark', 0.026259944)]]
